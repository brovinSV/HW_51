# %%
"""
До пункту видачі надійшли вироби з такими характеристиками:
Всього виробів – 13000 одиниць, з них виготовлено на першому заводі — 8000 од., вагою 13 кг., 
зі стандартним відхиленням по вазі 0.5 кг.. На другому — 5000 од., вагою 12 кг., зі стандартним відхиленням 
по вазі 0.7 кг. Доля якісних виробів, вироблених на першому заводі, становить 0.85. Доля якісних виробів, 
вироблених на другому заводі 0,8.

Завдання: 
Написати код, з використанням EM-алгоритму, для визначення ймовірності, на якому заводі був вироблений виріб.
"""

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import random
from scipy.stats import multivariate_normal
import warnings
warnings.filterwarnings("ignore")

# %%
# Ініціалізація параметрів
n = 13000 # кількість всього виробів
n1 = 8000 # кількість виробів першого заводу
n2 = 5000 # кількість виробів другого заводу

weight1 = 13 # вага виробів на першому заводі
weight2 = 12 # вага виробів на другому заводі

sigma1 = 0.5 # стандартне відхилення виробів першого заводу
sigma2 = 0.7 # стандартне відхилення виробів другого заводу

p1 = 0.85 # ймовірність отримання якісного виробу першого заводу
p2 = 0.8  # ймовірність отримання якісного виробу другого заводу

max_iter = 1000     # кількість ітерацій для роботи алгоритму
tolerance = 0.0001  # точніть методу

# %%
# Згенеруємо виборки випадкових величин згідно умов завдання
x1 = np.random.normal(weight1, sigma1, n1)   
x2 = np.random.normal(weight2, sigma2, n2)
x=np.hstack([x1, x2])    # об'єднаємо виборки в одну

# %%
data = np.concatenate((x), axis = None)
data
# Out:
# array([12.74423825, 11.66950555, 13.71945733, ..., 11.57686753,
#        12.08184975, 12.09667054])

# %%
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs

# %%
x1, y1 = make_blobs(8000, centers=1, cluster_std=0.5, center_box=(13,13))
x2, y2 = make_blobs(5000, centers=1, cluster_std=0.7, center_box=(12,12))
plt.scatter(x1[:, 0], x1[:, 1], color='blue', label='cluster 1')
plt.scatter(x2[:, 0], x2[:, 1], color='red', label='cluster 2')
plt.legend()
plt.show()

# %%
gm = GaussianMixture(n_components=2).fit(x.reshape(-1, 1))
gm.get_params()
# Out:
# {'covariance_type': 'full',
#  'init_params': 'kmeans',
#  'max_iter': 100,
#  'means_init': None,
#  'n_components': 2,
#  'n_init': 1,
#  'precisions_init': None,
#  'random_state': None,
#  'reg_covar': 1e-06,
#  'tol': 0.001,
#  'verbose': 0,
#  'verbose_interval': 10,
#  'warm_start': False,
#  'weights_init': None}

# %%
centers = gm.means_
print(centers)
# Out:
# [[11.93512601]
#  [13.00606486]]

# %%
pred = gm.predict(x.reshape(-1, 1))

# %%
plant1 = list(pred).count(0)/13000
plant2 = list(pred).count(1)/13000
print(f'Ймовірність, що деталь з першого заводу = {plant1}')
print(f'Ймовірність, що деталь з другого заводу = {plant2}')
# Out:
# Ймовірність, що деталь з першого заводу = 0.309
# Ймовірність, що деталь з другого заводу = 0.691
